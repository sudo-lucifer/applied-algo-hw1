# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hat_df = pd.read_csv('hat_benchmark.csv')
resizable_array_df = pd.read_csv('resizable_array_benchmark.csv')

# %%
amount_display = 20
index = np.arange(amount_display)
bar_width = 0.35

fig, ax = plt.subplots()
hat = ax.bar(index, hat_df['cpu_count'].head(amount_display), 0.35, label="HAT Array")
resizable_array = ax.bar(index + bar_width, resizable_array_df['cpu_count'].head(amount_display), 0.35, label="Resizable Array")
ax.set_xlabel('N operations')
ax.set_ylabel('total CPU cycles')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels([i for i in range(1,amount_display+1)])
ax.legend()

plt.show()
